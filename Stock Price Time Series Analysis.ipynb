# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.tsa.stattools as smt
import numpy as np

# %%
df= pd.read_csv('adjustedcp.csv')
df.dropna(inplace=True)
df.reset_index(drop=True)
print(df)
# Out:
#            Date      NIFTY50  TATA_STEEL  RELIANCE_INDUSTRIES  \
# 0    10-10-2013  6020.950195   10.569246           399.791229
# 1    11-10-2013  6096.200195   10.545273           401.348633
# 2    14-10-2013  6112.700195   10.329502           404.579437
# 3    15-10-2013  6089.049805   10.634318           403.417297
# 4    17-10-2013  6045.850098   10.620620           409.251404
# ..          ...          ...         ...                  ...
# 244  08-10-2014  7842.700195   15.940287           439.409943
# 245  09-10-2014  7960.549805   16.338663           447.830292
# 246  10-10-2014  7859.950195   15.657229           450.644928
# 247  13-10-2014  7884.250000   15.996201           449.354919
# 248  14-10-2014  7864.000000   15.936794           450.926392
#
#      HINDUSTAN_UNILIVER  TATA_COMMUNICATION  FINOLEX_CABLES
# 0           2567.266602         1202.994019      449.358765
# 1           2513.124756         1160.720459      451.793121
# 2           2553.226318         1167.330322      459.692261
# 3           2528.643066         1149.868530      454.823608
# 4           2537.904785         1148.043335      458.748352
# ..                  ...                 ...             ...
# 244         2507.850098         1863.949951     1077.750000
# 245         2519.550049         1850.300049     1080.550049
# 246         2499.399902         1837.800049     1072.550049
# 247         2511.300049         1807.250000     1040.400024
# 248         2513.649902         1831.099976     1056.699951
#
# [245 rows x 7 columns]

# %%
plt.scatter(df.Date,df.NIFTY50)
plt.xlabel('Date')
plt.ylabel('NIFTY50')
# Out:
# Text(0, 0.5, 'NIFTY50')

# %%
plt.scatter(df.Date,df.TATA_STEEL)
plt.xlabel('Date')
plt.ylabel('TATA_STEEL')
# Out:
# Text(0, 0.5, 'TATA_STEEL')

# %%
plt.scatter(df.Date,df.RELIANCE_INDUSTRIES)
plt.xlabel('Date')
plt.ylabel('RELIANCE_INDUSTRIES')
# Out:
# Text(0, 0.5, 'RELIANCE_INDUSTRIES')

# %%
plt.scatter(df.Date,df.HINDUSTAN_UNILIVER)
plt.xlabel('Date')
plt.ylabel('HINDUSTAN_UNILIVER')
# Out:
# Text(0, 0.5, 'HINDUSTAN_UNILIVER')

# %%
plt.scatter(df.Date,df.TATA_COMMUNICATION)
plt.xlabel('Date')
plt.ylabel('TATA_COMMUNICATION')
# Out:
# Text(0, 0.5, 'TATA_COMMUNICATION')

# %%
plt.scatter(df.Date,df.FINOLEX_CABLES)
plt.xlabel('Date')
plt.ylabel('FINOLEX_CABLES')
# Out:
# Text(0, 0.5, 'FINOLEX_CABLES')

# %%
ratio=np.zeros(len(df.index))
df['Return_Ratio']=ratio

# %%
for i in range(1,len(df.index)):
    df.loc[df.index[i],'Return_Ratio']=(df.loc[df.index[i],'NIFTY50']-df.loc[df.index[i-1],'NIFTY50'])/(df.loc[df.index[i],'NIFTY50'])
df.NIFTY50=df.Return_Ratio
df.Return_Ratio[0]=0

for i in range(1,len(df.index)):
    df.loc[df.index[i],'Return_Ratio']=(df.loc[df.index[i],'TATA_STEEL']-df.loc[df.index[i-1],'TATA_STEEL'])/(df.loc[df.index[i],'TATA_STEEL'])
df.TATA_STEEL=df.Return_Ratio
df.Return_Ratio[0]=0

for i in range(1,len(df.index)):
    df.loc[df.index[i],'Return_Ratio']=(df.loc[df.index[i],'RELIANCE_INDUSTRIES']-df.loc[df.index[i-1],'RELIANCE_INDUSTRIES'])/(df.loc[df.index[i],'RELIANCE_INDUSTRIES'])
df.RELIANCE_INDUSTRIES=df.Return_Ratio
df.Return_Ratio[0]=0

for i in range(1,len(df.index)):
    df.loc[df.index[i],'Return_Ratio']=(df.loc[df.index[i],'HINDUSTAN_UNILIVER']-df.loc[df.index[i-1],'HINDUSTAN_UNILIVER'])/(df.loc[df.index[i],'HINDUSTAN_UNILIVER'])
df.HINDUSTAN_UNILIVER=df.Return_Ratio
df.Return_Ratio[0]=0

for i in range(1,len(df.index)):
    df.loc[df.index[i],'Return_Ratio']=(df.loc[df.index[i],'TATA_COMMUNICATION']-df.loc[df.index[i-1],'TATA_COMMUNICATION'])/(df.loc[df.index[i],'TATA_COMMUNICATION'])
df.TATA_COMMUNICATION=df.Return_Ratio
df.Return_Ratio[0]=0

for i in range(1,len(df.index)):
    df.loc[df.index[i],'Return_Ratio']=(df.loc[df.index[i],'FINOLEX_CABLES']-df.loc[df.index[i-1],'FINOLEX_CABLES'])/(df.loc[df.index[i],'FINOLEX_CABLES'])
df.FINOLEX_CABLES=df.Return_Ratio
df.Return_Ratio[0]=0

df.Return_Ratio=0
print(df)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4296\1454207826.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Return_Ratio[0]=0
# C:\Users\admin\AppData\Local\Temp\ipykernel_4296\1454207826.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Return_Ratio[0]=0
# C:\Users\admin\AppData\Local\Temp\ipykernel_4296\1454207826.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Return_Ratio[0]=0
# C:\Users\admin\AppData\Local\Temp\ipykernel_4296\1454207826.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Return_Ratio[0]=0
# C:\Users\admin\AppData\Local\Temp\ipykernel_4296\1454207826.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Return_Ratio[0]=0
#            Date   NIFTY50  TATA_STEEL  RELIANCE_INDUSTRIES  \
# 0    10-10-2013  0.000000    0.000000             0.000000
# 1    11-10-2013  0.012344   -0.002273             0.003880
# 2    14-10-2013  0.002699   -0.020889             0.007986
# 3    15-10-2013 -0.003884    0.028663            -0.002881
# 4    17-10-2013 -0.007145   -0.001290             0.014256
# ..          ...       ...         ...                  ...
# 244  08-10-2014 -0.001237    0.035076             0.011263
# 245  09-10-2014  0.014804    0.024382             0.018803
# 246  10-10-2014 -0.012799   -0.043522             0.006246
# 247  13-10-2014  0.003082    0.021191            -0.002871
# 248  14-10-2014 -0.002575   -0.003728             0.003485
#
#      HINDUSTAN_UNILIVER  TATA_COMMUNICATION  FINOLEX_CABLES  Return_Ratio
# 0              0.000000            0.000000        0.000000             0
# 1             -0.021544           -0.036420        0.005388             0
# 2              0.015706            0.005662        0.017184             0
# 3             -0.009722           -0.015186       -0.010704             0
# 4              0.003649           -0.001590        0.008555             0
# ..                  ...                 ...             ...           ...
# 244            0.015531           -0.020280       -0.020970             0
# 245            0.004644           -0.007377        0.002591             0
# 246           -0.008062           -0.006802       -0.007459             0
# 247            0.004739           -0.016904       -0.030902             0
# 248            0.000935            0.013025        0.015425             0
#
# [245 rows x 8 columns]
# C:\Users\admin\AppData\Local\Temp\ipykernel_4296\1454207826.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Return_Ratio[0]=0

# %%
plt.scatter(df.Date,df.NIFTY50)
plt.xlabel('Date')
plt.ylabel('NIFTY50 (Return Ratio)')
# Out:
# Text(0, 0.5, 'NIFTY50 (Return Ratio)')

# %%
plt.scatter(df.Date,df.TATA_STEEL)
plt.xlabel('Date')
plt.ylabel('TATA_STEEL (Return Ratio)')
# Out:
# Text(0, 0.5, 'TATA_STEEL (Return Ratio)')

# %%
plt.scatter(df.Date,df.RELIANCE_INDUSTRIES)
plt.xlabel('Date')
plt.ylabel('RELIANCE_INDUSTRIES (Return Ratio)')
# Out:
# Text(0, 0.5, 'RELIANCE_INDUSTRIES (Return Ratio)')

# %%
plt.scatter(df.Date,df.HINDUSTAN_UNILIVER)
plt.xlabel('Date')
plt.ylabel('HINDUSTAN_UNILIVER (Return Ratio)')
# Out:
# Text(0, 0.5, 'HINDUSTAN_UNILIVER (Return Ratio)')

# %%
plt.scatter(df.Date,df.TATA_COMMUNICATION)
plt.xlabel('Date')
plt.ylabel('TATA_COMMUNICATION (Return Ratio)')
# Out:
# Text(0, 0.5, 'TATA_COMMUNICATION (Return Ratio)')

# %%
plt.scatter(df.Date,df.FINOLEX_CABLES)
plt.xlabel('Date')
plt.ylabel('FINOLEX_CABLES (Return Ratio)')
# Out:
# Text(0, 0.5, 'FINOLEX_CABLES (Return Ratio)')

# %%
df.drop('Return_Ratio', axis=1, inplace=True)

# %%
df.cov()
# Out:
#                       NIFTY50  TATA_STEEL  RELIANCE_INDUSTRIES  \
# NIFTY50              0.000072    0.000096             0.000087
# TATA_STEEL           0.000096    0.000485             0.000107
# RELIANCE_INDUSTRIES  0.000087    0.000107             0.000216
# HINDUSTAN_UNILIVER   0.000005    0.000024             0.000013
# TATA_COMMUNICATION   0.000003   -0.000006            -0.000007
# FINOLEX_CABLES       0.000020    0.000039             0.000002
#
#                      HINDUSTAN_UNILIVER  TATA_COMMUNICATION  FINOLEX_CABLES
# NIFTY50                        0.000005            0.000003        0.000020
# TATA_STEEL                     0.000024           -0.000006        0.000039
# RELIANCE_INDUSTRIES            0.000013           -0.000007        0.000002
# HINDUSTAN_UNILIVER             0.000112            0.000022        0.000016
# TATA_COMMUNICATION             0.000022            0.000317        0.000066
# FINOLEX_CABLES                 0.000016            0.000066        0.000728

# %%
plt.acorr(df.NIFTY50)
plt.title('Autocorrelation of NIFTY50')
# Out:
# Text(0.5, 1.0, 'Autocorrelation of NIFTY50')

# %%
plt.psd(df.NIFTY50, NFFT=245)
plt.title('PSD of NIFTY50')
# Out:
# Text(0.5, 1.0, 'PSD of NIFTY50')

# %%
plt.acorr(df.TATA_STEEL)
plt.title('Autocorrelation of TATA_STEEL')
# Out:
# Text(0.5, 1.0, 'Autocorrelation of TATA_STEEL')

# %%
plt.xcorr(df.NIFTY50,df.TATA_STEEL)
plt.title('Crosscorrelation of NIFTY50 and TATA_STEEL')
# Out:
# Text(0.5, 1.0, 'Crosscorrelation of NIFTY50 and TATA_STEEL')

# %%
plt.psd(df.TATA_STEEL, NFFT=245)
plt.title('PSD of TATA_STEEL')
# Out:
# Text(0.5, 1.0, 'PSD of TATA_STEEL')

# %%
plt.acorr(df.RELIANCE_INDUSTRIES)
plt.title('Autocorrelation of RELIANCE_INDUSTRIES')
# Out:
# Text(0.5, 1.0, 'Autocorrelation of RELIANCE_INDUSTRIES')

# %%
plt.xcorr(df.NIFTY50,df.RELIANCE_INDUSTRIES)
plt.title('Crosscorrelation of NIFTY50 and RELIANCE_INDUSTRIES')
# Out:
# Text(0.5, 1.0, 'Crosscorrelation of NIFTY50 and RELIANCE_INDUSTRIES')

# %%
plt.psd(df.RELIANCE_INDUSTRIES, NFFT=245)
plt.title('PSD of RELIANCE_INDUSTRIES')
# Out:
# Text(0.5, 1.0, 'PSD of RELIANCE_INDUSTRIES')

# %%
plt.acorr(df.HINDUSTAN_UNILIVER)
plt.title('Autocorrelation of HINDUSTAN_UNILIVER')
# Out:
# Text(0.5, 1.0, 'Autocorrelation of HINDUSTAN_UNILIVER')

# %%
plt.xcorr(df.NIFTY50,df.HINDUSTAN_UNILIVER)
plt.title('Crosscorrelation of NIFTY50 and HINDUSTAN_UNILIVER')
# Out:
# Text(0.5, 1.0, 'Crosscorrelation of NIFTY50 and HINDUSTAN_UNILIVER')

# %%
plt.psd(df.HINDUSTAN_UNILIVER, NFFT=245)
plt.title('PSD of HINDUSTAN_UNILIVER')
# Out:
# Text(0.5, 1.0, 'PSD of HINDUSTAN_UNILIVER')

# %%
plt.acorr(df.TATA_COMMUNICATION)
plt.title('Autocorrelation of TATA_COMMUNICATION')
# Out:
# Text(0.5, 1.0, 'Autocorrelation of TATA_COMMUNICATION')

# %%
plt.xcorr(df.NIFTY50,df.TATA_COMMUNICATION)
plt.title('Crosscorrelation of NIFTY50 and TATA_COMMUNICATION')
# Out:
# Text(0.5, 1.0, 'Crosscorrelation of NIFTY50 and TATA_COMMUNICATION')

# %%
plt.psd(df.TATA_COMMUNICATION, NFFT=245)
plt.title('PSD of TATA_COMMUNICATION')
# Out:
# Text(0.5, 1.0, 'PSD of TATA_COMMUNICATION')

# %%
plt.acorr(df.FINOLEX_CABLES)
plt.title('Autocorrelation of FINOLEX _CABLES')
# Out:
# Text(0.5, 1.0, 'Autocorrelation of FINOLEX _CABLES')

# %%
plt.xcorr(df.NIFTY50,df.FINOLEX_CABLES)
plt.title('Crosscorrelation of NIFTY50 and FINOLEX_CABLES')
# Out:
# Text(0.5, 1.0, 'Crosscorrelation of NIFTY50 and FINOLEX_CABLES')

# %%
plt.psd(df.FINOLEX_CABLES, NFFT=245)
plt.title('PSD of FINOLEX_CABLES')
# Out:
# Text(0.5, 1.0, 'PSD of FINOLEX_CABLES')
